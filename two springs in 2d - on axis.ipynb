# %%
# %run Calculating.ipynb

# %%
# %run Plotting.ipynb

# %%
R = np.array([
    [0., 0],
    [1, 0],
    [-1, 0],
])

# %%
springs = [(0,1),(0,2)]

# %%
H, l, v, D = calc(R, springs)

# %%
plot(R, D[:3], .5)

# %%
plot(R, D[3:], .5)
